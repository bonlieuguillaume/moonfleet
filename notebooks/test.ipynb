# %%
import geopandas as gpd

# Si shapefile
detections = gpd.read_file(r"C:\Users\guigu\Downloads\ShipDetections_Point.shp")

# Si CSV
#import pandas as pd
#detections = pd.read_csv(r"C:\Users\guigu\Downloads\total.csv")

# Afficher les premières lignes
detections.head()

# Voir toutes les colonnes disponibles
# print(detections.columns)

# Statistiques rapides
detections.describe()
